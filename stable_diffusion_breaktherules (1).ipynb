# %%
# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !apt -y install -qq aria2
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !pip install -q xformers==0.0.16 triton==2.0.0 -U

# !git clone https://github.com/Xelszy/stablebreaktest /content/breaktherules
# !python /content/breaktherules/stablebreaktest.py

# %cd /content/stablebreaktest
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ixelszy/For-upload-folder/resolve/main/anime_model_goodfornsfw.safetensors -d /content/stablebreaktest/models/Stable-diffusion -o model_nsfw.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/p1atdev/graupel-v1/resolve/main/graupel-v1-nobody-fp16.safetensors -d /content/stablebreaktest/models/Stable-diffusion -o graupel.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ixelszy/For-upload-folder/resolve/main/merge.3.safetensors -d /content/stablebreaktest/models/Stable-diffusion -o merge3realistic.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /content/stablebreaktest/models/Stable-diffusion -o vae-ft.vae.pt

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stablebreaktest/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stablebreaktest/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/stablebreaktest/modules/shared.py

# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple
# Out:
# /content
# env: TF_CPP_MIN_LOG_LEVEL=1
# 27 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2023-04-26 06:11:24--  http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203696 (199K) [application/x-debian-package]
# Saving to: ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’
#
# libgoogle-perftools 100%[===================>] 198.92K   280KB/s    in 0.7s
#
# 2023-04-26 06:11:25 (280 KB/s) - ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’ saved [203696/203696]
#
# --2023-04-26 06:11:26--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.223, 185.125.189.222, 2620:2d:4000:1001::8004, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.223|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274642/google-perftools_2.5-2.2ubuntu3_all.deb [following]
# --2023-04-26 06:11:26--  https://launchpadlibrarian.net/367274642/google-perftools_2.5-2.2ubuntu3_all.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.229, 185.125.189.228, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294224 (287K) [application/x-debian-package]
# Saving to: ‘google-perftools_2.5-2.2ubuntu3_all.deb’
#
# google-perftools_2. 100%[===================>] 287.33K   376KB/s    in 0.8s
#
# 2023-04-26 06:11:28 (376 KB/s) - ‘google-perftools_2.5-2.2ubuntu3_all.deb’ saved [294224/294224]
#
# --2023-04-26 06:11:28--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.223, 185.125.189.222, 2620:2d:4000:1001::8004, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.223|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274648/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb [following]
# --2023-04-26 06:11:29--  https://launchpadlibrarian.net/367274648/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.229, 185.125.189.228, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91644 (89K) [application/x-debian-package]
# Saving to: ‘libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb’
#
# libtcmalloc-minimal 100%[===================>]  89.50K   223KB/s    in 0.4s
#
# 2023-04-26 06:11:30 (223 KB/s) - ‘libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb’ saved [91644/91644]
#
# --2023-04-26 06:11:30--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.223, 185.125.189.222, 2620:2d:4000:1001::8004, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.223|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274647/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb [following]
# --2023-04-26 06:11:31--  https://launchpadlibrarian.net/367274647/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.229, 185.125.189.228, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189628 (185K) [application/x-debian-package]
# Saving to: ‘libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb’
#
# libgoogle-perftools 100%[===================>] 185.18K   275KB/s    in 0.7s
#
# 2023-04-26 06:11:32 (275 KB/s) - ‘libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb’ saved [189628/189628]
#
# The following NEW packages will be installed:
#   libunwind-dev
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 472 kB of archives.
# After this operation, 4,164 kB of additional disk space will be used.
# Selecting previously unselected package libunwind-dev:amd64.
# (Reading database ... 122400 files and directories currently installed.)
# Preparing to unpack .../libunwind-dev_1.2.1-9ubuntu0.1_amd64.deb ...
# Unpacking libunwind-dev:amd64 (1.2.1-9ubuntu0.1) ...
# Setting up libunwind-dev:amd64 (1.2.1-9ubuntu0.1) ...
# Processing triggers for man-db (2.9.1-1) ...
# dpkg: warning: downgrading google-perftools from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# (Reading database ... 122453 files and directories currently installed.)
# Preparing to unpack google-perftools_2.5-2.2ubuntu3_all.deb ...
# Unpacking google-perftools (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# dpkg: warning: downgrading libgoogle-perftools4:amd64 from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# Preparing to unpack libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools4 (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# Selecting previously unselected package libgoogle-perftools-dev.
# Preparing to unpack libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# dpkg: warning: downgrading libtcmalloc-minimal4:amd64 from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# Preparing to unpack libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4 (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# Setting up libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# Setting up google-perftools (2.5-2.2ubuntu3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# env: LD_PRELOAD=libtcmalloc.so
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 31 not upgraded.
# Need to get 1,475 kB of archives.
# After this operation, 5,959 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 122544 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# Unpacking aria2 (1.35.0-1build1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# Setting up aria2 (1.35.0-1build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 120.4 MB/s eta 0:00:01tcmalloc: large alloc 1977925632 bytes == 0x25ac000 @  0x7f987cae81e7 0x6e6e9e 0x629594 0x685a9c 0x564b38 0x564bcf 0x53f72a 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c1d3 0x62c60f 0x5ab826 0x62c994 0x5ac335 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x548478 0x537b6a 0x6a2ad6
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 117.9 MB/s eta 0:00:01tcmalloc: large alloc 2472411136 bytes == 0x783f8000 @  0x7f987cae9615 0x629504 0x685a9c 0x564b38 0x564bcf 0x53f72a 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c1d3 0x62c60f 0x5ab826 0x62c994 0x5ac335 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x548478 0x537b6a 0x6a2ad6 0x5afd01
# tcmalloc: large alloc 1977925632 bytes == 0x25ac000 @  0x7f987cae81e7 0x62e9b6 0x630070 0x53f72a 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x548478 0x537b6a 0x6a2ad6 0x5afd01 0x62c1d3 0x5482c4 0x5afd01 0x5a9eb4 0x5483e1 0x5afd01 0x62c1d3 0x62c60f 0x5ab826 0x5a9eb4 0x5483e1 0x5ac335 0x53d523 0x5abacc 0x53d523 0x5abacc 0x53d523
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 872.3 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 64.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 44.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 70.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 MB 14.3 MB/s eta 0:00:00
# Cloning into '/content/breaktherules'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 54 (delta 23), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (54/54), 17.19 KiB | 1.56 MiB/s, done.
# Cloning into '/content/stablebreaktest'...
# remote: Enumerating objects: 17762, done.
# remote: Total 17762 (delta 0), reused 0 (delta 0), pack-reused 17762
# Receiving objects: 100% (17762/17762), 28.32 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (12405/12405), done.
# Cloning into '/content/stablebreaktest/extensions/sd-webui-additional-networks'...
# remote: Enumerating objects: 743, done.
# remote: Counting objects: 100% (273/273), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 743 (delta 201), reused 171 (delta 168), pack-reused 470
# Receiving objects: 100% (743/743), 241.47 KiB | 17.25 MiB/s, done.
# Resolving deltas: 100% (410/410), done.
# Cloning into '/content/stablebreaktest/extensions/tag-autocomplete'...
# remote: Enumerating objects: 1129, done.
# remote: Counting objects: 100% (1129/1129), done.
# remote: Compressing objects: 100% (448/448), done.
# remote: Total 1129 (delta 636), reused 1075 (delta 620), pack-reused 0
# Receiving objects: 100% (1129/1129), 3.82 MiB | 18.09 MiB/s, done.
# Resolving deltas: 100% (636/636), done.
# Cloning into '/content/stablebreaktest/extensions/stable-diffusion-webui-two-shot'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 176 (delta 31), reused 42 (delta 24), pack-reused 114
# Receiving objects: 100% (176/176), 22.22 MiB | 14.50 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3319d7|OK  |   362MiB/s|/content/stablebreaktest/models/ESRGAN/4x-UltraSharp.pth
#
# Status Legend:
# (OK):download completed.
# --2023-04-26 06:14:18--  https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 533 [text/plain]
# Saving to: ‘/content/stablebreaktest/scripts/run_n_times.py’
#
# /content/stablebrea 100%[===================>]     533  --.-KB/s    in 0s
#
# 2023-04-26 06:14:18 (38.3 MB/s) - ‘/content/stablebreaktest/scripts/run_n_times.py’ saved [533/533]
#
# Cloning into '/content/stablebreaktest/extensions/sd-webui-supermerger'...
# remote: Enumerating objects: 736, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 736 (delta 130), reused 109 (delta 109), pack-reused 577
# Receiving objects: 100% (736/736), 4.72 MiB | 19.51 MiB/s, done.
# Resolving deltas: 100% (371/371), done.
# Cloning into '/content/stablebreaktest/extensions/sd-webui-llul'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 138 (delta 60), reused 116 (delta 40), pack-reused 0
# Receiving objects: 100% (138/138), 13.20 MiB | 6.81 MiB/s, done.
# Resolving deltas: 100% (60/60), done.
# Cloning into '/content/stablebreaktest/extensions/db-storage1111'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 30 (delta 11), reused 26 (delta 7), pack-reused 0
# Unpacking objects: 100% (30/30), 5.21 KiB | 1.04 MiB/s, done.
# Cloning into '/content/stablebreaktest/extensions/stable-diffusion-webui-model-toolkit'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 154 (delta 76), reused 100 (delta 41), pack-reused 0
# Receiving objects: 100% (154/154), 54.92 KiB | 803.00 KiB/s, done.
# Resolving deltas: 100% (76/76), done.
# Cloning into '/content/stablebreaktest/extensions/a1111-sd-webui-locon'...
# remote: Enumerating objects: 178, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 178 (delta 11), reused 8 (delta 3), pack-reused 150
# Receiving objects: 100% (178/178), 43.42 KiB | 14.47 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# Cloning into '/content/stablebreaktest/extensions/sd-civitai-browser'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 163 (delta 37), reused 28 (delta 23), pack-reused 108
# Receiving objects: 100% (163/163), 39.30 KiB | 13.10 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# Cloning into '/content/stablebreaktest/extensions/sd-webui-controlnet'...
# remote: Enumerating objects: 5468, done.
# remote: Counting objects: 100% (1749/1749), done.
# remote: Compressing objects: 100% (207/207), done.
# remote: Total 5468 (delta 1576), reused 1604 (delta 1540), pack-reused 3719
# Receiving objects: 100% (5468/5468), 13.14 MiB | 8.47 MiB/s, done.
# Resolving deltas: 100% (2897/2897), done.
# Cloning into '/content/stablebreaktest/extensions/openpose-editor'...
# remote: Enumerating objects: 361, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 361 (delta 75), reused 66 (delta 60), pack-reused 266
# Receiving objects: 100% (361/361), 299.61 KiB | 24.97 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# Cloning into '/content/stablebreaktest/extensions/sd-webui-depth-lib'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 98 (delta 19), reused 77 (delta 9), pack-reused 0
# Unpacking objects: 100% (98/98), 5.76 MiB | 8.06 MiB/s, done.
# Cloning into '/content/stablebreaktest/extensions/posex'...
# remote: Enumerating objects: 402, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 402 (delta 19), reused 29 (delta 16), pack-reused 364
# Receiving objects: 100% (402/402), 11.39 MiB | 15.62 MiB/s, done.
# Resolving deltas: 100% (194/194), done.
# Cloning into '/content/stablebreaktest/extensions/Umi-AI'...
# remote: Enumerating objects: 3688, done.
# remote: Counting objects: 100% (1244/1244), done.
# remote: Compressing objects: 100% (1190/1190), done.
# remote: Total 3688 (delta 47), reused 1224 (delta 45), pack-reused 2444
# Receiving objects: 100% (3688/3688), 1014.14 MiB | 26.44 MiB/s, done.
# Resolving deltas: 100% (490/490), done.
# Updating files: 100% (2490/2490), done.
# Cloning into '/content/stablebreaktest/extensions/sd-webui-cutoff'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 102 (delta 45), reused 91 (delta 34), pack-reused 0
# Receiving objects: 100% (102/102), 19.91 MiB | 7.00 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# Cloning into '/content/stablebreaktest/extensions/sd-webui-tunnels'...
# remote: Enumerating objects: 367, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 367 (delta 164), reused 181 (delta 128), pack-reused 147
# Receiving objects: 100% (367/367), 66.76 KiB | 16.69 MiB/s, done.
# Resolving deltas: 100% (181/181), done.
# Cloning into '/content/stablebreaktest/extensions/stable-diffusion-webui-images-browser'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 143 (delta 25), reused 21 (delta 21), pack-reused 109
# Receiving objects: 100% (143/143), 37.96 KiB | 12.65 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# Cloning into '/content/stablebreaktest/extensions/sdweb-merge-block-weighted-gui'...
# remote: Enumerating objects: 281, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 281 (delta 43), reused 33 (delta 29), pack-reused 220
# Receiving objects: 100% (281/281), 39.30 MiB | 17.69 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# Cloning into '/content/stablebreaktest/extensions/stable-diffusion-webui-huggingface'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 121 (delta 12), reused 10 (delta 10), pack-reused 106
# Receiving objects: 100% (121/121), 28.80 KiB | 9.60 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# Cloning into '/content/stablebreaktest/extensions/multidiffusion-upscaler-for-automatic1111'...
# remote: Enumerating objects: 835, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 835 (delta 21), reused 22 (delta 20), pack-reused 801
# Receiving objects: 100% (835/835), 1.06 MiB | 24.18 MiB/s, done.
# Resolving deltas: 100% (444/444), done.
# Cloning into '/content/stablebreaktest/extensions/batchlinks-webui'...
# remote: Enumerating objects: 489, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 489 (delta 140), reused 149 (delta 92), pack-reused 277
# Receiving objects: 100% (489/489), 4.34 MiB | 17.03 MiB/s, done.
# Resolving deltas: 100% (264/264), done.
# HEAD is now at a9fed7c3 Merge pull request #8503 from mcmonkey4eva/filename-length-limit-fix
# fatal: cannot change to '/content/stablebreaktest/repositories/stable-diffusion-stability-ai': No such file or directory
# Exception: Command 'git -C /content/stablebreaktest/repositories/stable-diffusion-stability-ai reset --hard' returned non-zero exit status 128.
# /content/stablebreaktest
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a20a5f|OK  |   140MiB/s|/content/stablebreaktest/models/Stable-diffusion/model_nsfw.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d2b0ee|OK  |   135MiB/s|/content/stablebreaktest/models/Stable-diffusion/graupel.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0782c3|OK  |   132MiB/s|/content/stablebreaktest/models/Stable-diffusion/merge3realistic.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ea1eb4|OK  |   306MiB/s|/content/stablebreaktest/models/Stable-diffusion/vae-ft.vae.pt
#
# Status Legend:
# (OK):download completed.
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: a9fed7c364061ae6efb37f797b6b522cb3cf7aa2
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into /content/stablebreaktest/repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into /content/stablebreaktest/repositories/taming-transformers...
# Cloning K-diffusion into /content/stablebreaktest/repositories/k-diffusion...
# Cloning CodeFormer into /content/stablebreaktest/repositories/CodeFormer...
# Cloning BLIP into /content/stablebreaktest/repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
#
# Installing requirements for db-storage1111
#
# Installing diffusers
#
# Installing sd-webui-controlnet requirement: mediapipe
# Installing sd-webui-controlnet requirement: svglib
# Installing sd-webui-controlnet requirement: fvcore
#
# Installing pycloudflared
#
# Installing requirements for CivitAI Browser
#
#
# Launching Web UI with arguments: --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple
# 2023-04-26 06:19:56.656822: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Additional Network extension not installed, Only hijack built-in lora
# LoCon Extension hijack built-in lora successfully
# [AddNet] Updating model hashes...
# 0it [00:00, ?it/s]
# [AddNet] Updating model hashes...
# 0it [00:00, ?it/s]
# ControlNet v1.1.112
# ControlNet v1.1.112
# all detected, remote.moe trying to connect...
# Warning: Permanently added 'localhost.run,54.161.197.247' (RSA) to the list of known hosts.
# Warning: Permanently added 'remote.moe,159.69.126.209' (ECDSA) to the list of known hosts.
# all detected, cloudflared trying to connect...
# Download cloudflared...: 100% 34.9M/34.9M [00:00<00:00, 420MB/s]
# Calculating sha256 for /content/stablebreaktest/models/Stable-diffusion/model_nsfw.safetensors: 946dcb22ebc98914bbe4db82909ef4bb423c4179c691a3e5482248170ddcdea1
# Loading weights [946dcb22eb] from /content/stablebreaktest/models/Stable-diffusion/model_nsfw.safetensors
# Creating model from config: /content/stablebreaktest/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:00<00:00, 1.04MB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 1.26MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 127kB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 307kB/s]
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 1.55MB/s]
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(882): Censor via Steam Highstep, Character Turner and Rotator, Blindfolded, Albino Skin, Censor via Steam Medstep, Inside Jar, Runny Makeup Mascara by Master_Corneo, Dark Skin by Shreddertheman, Ahegao Expression, Censor via Steam Lowstep, Censor via Hair, NEGS Bad Artist OG, NEGS Bad Prompt v1, NEGS Bad Image v2, NEGS Bad Image v1, NEGS Bad Hands, NEGS Deep Negative v1.75T, NEGS Bad Artist Anime, NEGS ART Nebula Magic-Style Fantasy and Galaxies by faeia, NEGS Bad Image v3, NEGS Bad Image v4, NEGS Bad Prompt v2, CHAR-F Blue Archive Akeboshi Himari, CHAR-F LoL Seraphine, CHAR-F Azur Lane Unicorn School Uniform, CHAR-F Blue Archive Sorasaki Hina, CHAR-F Overwatch Tracer by Master_Corneo, CHAR-F vTuber Ouro Kronii, CHAR-F vTuber Houshou Marine by Shreddertheman, CHAR-F Girls Frontline Ouroboros, CHAR-F vTuber Anya Melfissa v2, CHAR-F Idolmaster Amana Osaki, CHAR-F Arknights Texas the Omertosa, CHAR-F Genshin Columbina, CHAR-F Kancolle Taigei, CHAR-F Azur Lane Kashino Swimsuit, CHAR-F vTuber IRyS, CHAR-F The Legend of Mir Lady, CHAR-F SpyxFamily Anya Forger v1, CHAR-F Re-Zero Emilia by UmCaraManeiro, CHAR-F vTuber Mori Calliope, CHAR-F vTuber Airani Iofifteen, CHAR-F Azur Lane Queen Elizabeth, CHAR-F Marvel Powergirl T1 by agntperseus, CHAR-F Idolmaster Anzu Futaba, CHAR-F Genshin Arlecchino v2, CHAR-F Arknights W, CHAR-F Blue Archive Arona, CHAR-F Idolmaster Mei Izumi, CHAR-F Idolmaster Yuika Mitsumine, CHAR-F NISANJI EN Elira Pendora v3, CHAR-F Azur Lane Belfast, CHAR-F Pretty Derby Sweep Tosho, CHAR-F My Hero Academia Toga Himiko by Ekune, CHAR-F Genshin Eula by PeePa, CHAR-F Pretty Derby Yaeno Muteki, CHAR-F Plastic Memories Isla, CHAR-F Overwatch Dva Black Cat by Master_Corneo, CHAR-F Lycoris Recoil Nishikigi Chisato, CHAR-F FF Series Tifa Lockheart v1, CHAR-F Kantai Northern Princess, CHAR-F Konosuba Megumin v2, CHAR-F Overwatch Kiriko for WD1.3 by kattoboiy, CHAR-F vTuber Laplus Darkness v2, CHAR-F One Piece Yamato v1, CHAR-F Blue Archive Uzawa Reisa, CHAR-F Grey Ravens No 21 XXI, CHAR-F MTG Tamiyo, CHAR-F Call of the Night Nazuna Nanakusa WEAK, CHAR-F Girls Frontline M200, CHAR-F Pretty Derby Curren Chan, CHAR-F Arknights Angelina, CHAR-F vTuber Luo Tianyi, CHAR-F Idolmaster Hiori Kazano, CHAR-F Blue Archive Sunohara Shun v1, CHAR-F Pretty Derby Mejiro Dober, CHAR-F Shadowverse Olivia, CHAR-F Girls Frontline Destroyer, CHAR-F My Dear Moments Atri, CHAR-F Azur Lane Illustrious Maiden, CHAR-F Pokemon Cynthia Shirone, CHAR-F Persona Sakura Futaba v1, CHAR-F Ace Attorney Geiru Toneido by Shurik, CHAR-F Overwatch Widowmaker v2 by Master_Corneo, CHAR-F vTuber Nana7mi, CHAR-F Honkai Elysia, CHAR-F Genshin Yoimiya by King O Lora, CHAR-F Pretty Derby Seiun Sky, CHAR-F Azur Lane Sirius v2, CHAR-F SpyxFamily Yor Forger Assassin Dress by Master_Corneo, CHAR-F Honkai Griseo v1, CHAR-F vTuber Laplus Darkness, CHAR-F FF Series Scarlet by icepick912, CHAR-F Blue Archive Tsukiyuki Miyako, CHAR-F vTuber Vestia Zeta, CHAR-F Arknights Dusk, CHAR-F Love is War Shirogane Kei, CHAR-F Azur Lane Nagato, CHAR-F vTuber Tsunomaki Watame, CHAR-F Blue Archive Izuna v2, CHAR-F vTuber Shylily by JustNeutral, CHAR-F Arknights Surtr, CHAR-F vTuber Korone Inugami, CHAR-F vTuber Anzu Uchu Drill Hair, CHAR-F Girls Frontline AUG, CHAR-F Halo Series Cortana by FreeScotman, CHAR-F Genshin Sangonomiya Kokomi, CHAR-F vTuber Guwr Gura v3, CHAR-F SpyxFamily Anya, CHAR-F vTuber Kobo Kanaeru v1, CHAR-F Honkai Griseo v2, CHAR-F Mist Train Girls Sakurakouji Luna v2, CHAR-F One Piece Robin, CHAR-F Blue Archive Iochi Mari (Gym ver.), CHAR-F Disney Princess Jasmine by Shurik, CHAR-F Love Live Rina Tennoji, CHAR-F Love is War Iino Miko, CHAR-F vTuber Yukihana Lamy, CHAR-F Idolmaster Kiriko Yukoku, CHAR-F Idolmaster Asahi Serizawa, CHAR-F Revue Starlight Aijou Karen, CHAR-F Fate Tamano No Mae, CHAR-F Azur Lane Sheffield v2, CHAR-F Avatar Series Azula by Shurik, CHAR-F Genshin Gorou China, CHAR-F Arknights Nian, CHAR-F Blue Archive Takanash ...
# Textual inversion embeddings skipped(21): CONCEPT Car Helper Detailed Automotives for SD2.0 by stille_willem, NEGS Low Resolution Fix VHighStep by tolerantpancake, NEGS Low Resolution Fix HighStep by tolerantpancake, NEGS Low Resolution Fix LowStep by tolerantpancake, NEGS Low Resolution Fix VLowStep by tolerantpancake, NEGS Low Resolution Fix MedStep by tolerantpancake, CHAR-F Kancolle Johnston by Zevuchi, IRL-M Chris Hemsworth for SD2.1 by aslansbane, IRL-M Jeremy Allen White by aslansbane, IRL-F Ana De Armas by aslansbane, ART Milo Manara-Style Italian Artist by noriko_takaeda, CHAR-M Sonic Series OG Movie Ugly Sonic by minimaxir, ART Realistic Ancient Rome-Style by aslansbane, ART Lavastyle for SD2.x by Redw04, ART Verbose Painting-Style for SD2.1 by EldritchAdam, ART Max Twain-Style Barbie Bratz Girls by giannidb, ART SD2 Warm Anime Screencap by Conflictx, ART Dishonored-Style Art by spaablauw, ART Classical Rennaisance Paintings by EldritchAdam, ART Horror Atmosphere by GamingDaveUK, ART Tungsten Dispo Airbrushed Glowing Girls by fzbuzz
# Model loaded in 34.1s (calculate hash: 13.6s, load weights from disk: 0.2s, create model: 15.2s, apply weights to model: 2.6s, load textual inversion embeddings: 2.4s).
# Public WebUI Colab URL: http://34gzyjrd55azwih3z6t6b7fxi4fefcdsjo4mq7ykf5545a27hboa.remote.moe
# Public WebUI Colab URL: https://e6ecd1e2-020c-45ff.gradio.live
# Public WebUI Colab URL: https://6456f44b546111.lhr.life
# Public WebUI Colab URL: https://rebates-tracks-trade-tops.trycloudflare.com
# Startup time: 88.6s (import gradio: 2.8s, import ldm: 7.8s, other imports: 5.0s, list extensions: 2.1s, setup codeformer: 0.2s, load scripts: 28.1s, load SD checkpoint: 34.2s, create ui: 8.1s, gradio launch: 0.3s).
# Loading /content/stablebreaktest/models/Stable-diffusion/model_nsfw.safetensors...
# Loading /content/stablebreaktest/models/Stable-diffusion/merge3realistic.safetensors...
# Merging...
# 100% 1330/1330 [00:17<00:00, 76.81it/s]
# Saving to /content/stablebreaktest/models/Stable-diffusion/0.95(merge3realistic) + 0.05(model_nsfw).safetensors...
# Checkpoint saved to /content/stablebreaktest/models/Stable-diffusion/0.95(merge3realistic) + 0.05(model_nsfw).safetensors.
# models/Stable-diffusion/LOFI/lofi_V21.ckpt successfully downloaded.
# Loading /content/stablebreaktest/models/Stable-diffusion/LOFI/lofi_V21.ckpt...
# Loading /content/stablebreaktest/models/Stable-diffusion/merge3realistic.safetensors...
# Merging...
# 100% 1330/1330 [00:19<00:00, 68.55it/s]
# Saving to /content/stablebreaktest/models/Stable-diffusion/1.ckpt...
# Checkpoint saved to /content/stablebreaktest/models/Stable-diffusion/1.ckpt.
# Loading VAE weights specified in settings: /content/stablebreaktest/models/Stable-diffusion/vae-ft.vae.pt
# Applying xformers cross attention optimization.
# VAE weights loaded.
#
# Total progress: 0it [00:00, ?it/s]X/Y/Z plot will create 3 images on 1 3x1 grid. (Total steps to process: 120)
# Calculating sha256 for /content/stablebreaktest/models/Stable-diffusion/LOFI/lofi_V21.ckpt: c458d125d9d0a7483321703d929ac61fc29aacc5e2594c3fe50792f6ee82b177
# Loading weights [c458d125d9] from /content/stablebreaktest/models/Stable-diffusion/LOFI/lofi_V21.ckpt
# Loading VAE weights specified in settings: /content/stablebreaktest/models/Stable-diffusion/vae-ft.vae.pt
# Applying xformers cross attention optimization.
# Weights loaded in 39.6s (calculate hash: 25.0s, load weights from disk: 11.1s, apply weights to model: 0.7s, load VAE: 1.9s, move model to device: 0.9s).
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:07<02:27,  7.78s/it]
#  10% 2/20 [00:08<01:04,  3.59s/it]
#  15% 3/20 [00:09<00:38,  2.25s/it]
#  20% 4/20 [00:09<00:25,  1.62s/it]
#  25% 5/20 [00:10<00:19,  1.27s/it]
#  30% 6/20 [00:11<00:14,  1.06s/it]
#  35% 7/20 [00:11<00:12,  1.08it/s]
#  40% 8/20 [00:12<00:10,  1.20it/s]
#  45% 9/20 [00:12<00:08,  1.28it/s]
#  50% 10/20 [00:13<00:07,  1.35it/s]
#  55% 11/20 [00:14<00:06,  1.40it/s]
#  60% 12/20 [00:14<00:05,  1.43it/s]
#  65% 13/20 [00:15<00:04,  1.44it/s]
#  70% 14/20 [00:16<00:04,  1.38it/s]
#  75% 15/20 [00:17<00:03,  1.41it/s]
#  80% 16/20 [00:17<00:02,  1.44it/s]
#  85% 17/20 [00:18<00:02,  1.46it/s]
#  90% 18/20 [00:19<00:01,  1.47it/s]
#  95% 19/20 [00:19<00:00,  1.48it/s]
# 100% 20/20 [00:20<00:00,  1.00s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:08<02:48,  8.85s/it]
#  10% 2/20 [00:11<01:35,  5.32s/it]
#  15% 3/20 [00:14<01:11,  4.19s/it]
#  20% 4/20 [00:17<00:58,  3.66s/it]
#  25% 5/20 [00:20<00:50,  3.36s/it]
#  30% 6/20 [00:23<00:44,  3.17s/it]
#  35% 7/20 [00:25<00:39,  3.05s/it]
#  40% 8/20 [00:28<00:35,  2.96s/it]
#  45% 9/20 [00:31<00:31,  2.90s/it]
#  50% 10/20 [00:34<00:28,  2.87s/it]
#  55% 11/20 [00:36<00:25,  2.84s/it]
#  60% 12/20 [00:39<00:22,  2.83s/it]
#  65% 13/20 [00:42<00:19,  2.84s/it]
#  70% 14/20 [00:45<00:16,  2.82s/it]
#  75% 15/20 [00:48<00:13,  2.79s/it]
#  80% 16/20 [00:50<00:11,  2.78s/it]
#  85% 17/20 [00:53<00:08,  2.77s/it]
#  90% 18/20 [00:56<00:05,  2.77s/it]
#  95% 19/20 [00:59<00:02,  2.77s/it]
# 100% 20/20 [01:00<00:00,  3.03s/it]
